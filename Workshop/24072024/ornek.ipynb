# %%
import pandas as pd

# %%
df = pd.read_json(r"dosya1.json")

# %%
import numpy as np

# %%
var1 = "$2,474.98"
var1 = var1[1:]
var1 = var1.replace(",","")

# %%
def fonk(var1):
    # var1 = "$2,474.98"
    var1 = var1[1:]
    var1 = var1.replace(",","")
    return var1
df["balance_temiz"] =  df["balance"].apply(fonk)

# %%
df["balance_temiz"] = df["balance_temiz"].astype(np.float64)

# %%
df["balance_temiz"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.to_csv("sonuc.csv")

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
liste = [random.random() for i in range(10000)]
plt.hist(np.array(liste));

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
liste = [np.random.random() for i in range(10000)]
plt.hist(np.array(liste));

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
liste = [np.random.randn() for i in range(10000)]
plt.hist(np.array(liste));
